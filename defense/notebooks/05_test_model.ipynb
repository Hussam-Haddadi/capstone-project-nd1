# %% [markdown]
# # 05 · Test Model Interactively
#
# **للـ frontend team** — جرّب الموديل على أي رسالة.
#
# ---

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path().resolve().parent.parent))

from defense.src.detector import PhishingDetector
detector = PhishingDetector('../models/defence_model.pkl')
print(f'✅ Model loaded: {detector}')
# Out:
# ✅ Model loaded: PhishingDetector(version='v4_golden', trained_on=2462 samples)

# %% [markdown]
# ## ✏️ اختبر رسالة واحدة

# %%
message = 'زاجل: شحنتك في الطريق. الموعد المتوقع: الأحد. علشان تتابع شحنتك، اضغط هنا: www.mobily.com.cc'

r = detector.predict(message)
icon = '🔴' if r['is_phishing'] else '🟢'
print(f'{icon} {r["label_ar"]}')
print(f'   Risk: {r["risk_score"]:.1f} | Confidence: {r["confidence"]} | Method: {r["detection_method"]}')
for flag in r['flags']:
    print(f'   • {flag}')
# Out:
# 🔴 تصيد احتيالي
#    Risk: 12.0 | Confidence: high | Method: ml+rules
#    • رابط بنطاق مشبوه
#    • انتحال هوية علامة تجارية
#    • تقليد نطاق حقيقي
#    • كلمات حث (1)

# %% [markdown]
# ## اختبار عدة رسائل

# %%
messages = [
    'تحذير! تم اكتشاف تسجيل دخول. حدّث بياناتك على bank-secure.online',
    'مكتب خدمات استقدام للتواصل 0501234567',
    'ولي العهد وجه بمشروع جديد http://bit.ly/2JBe1lG',
    'تم تفعيل باقتك الشهرية بنجاح. شكراً لاختيارك زين',
    'الراجحي: عملية شراء 500 ريال. للاستفسار: 920003344',
    'مرحبا نبيل رئيس مشروع نيوم: ولي العهد وجه بإعداد لوائح ملائمة للاستثمار في المشروع http://bit.ly/2JBe1lG',
]

for msg in messages:
    r = detector.predict(msg)
    icon = '🔴' if r['is_phishing'] else '🟢'
    print(f'{icon} {r["label_ar"]:15s} | risk={r["risk_score"]:5.1f} | {msg[:65]}')
# Out:
# 🔴 تصيد احتيالي    | risk=  2.5 | تحذير! تم اكتشاف تسجيل دخول. حدّث بياناتك على bank-secure.online
# 🔴 تصيد احتيالي    | risk=  7.0 | مكتب خدمات استقدام للتواصل 0501234567
# 🔴 تصيد احتيالي    | risk=  4.0 | ولي العهد وجه بمشروع جديد http://bit.ly/2JBe1lG
# 🟢 رسالة آمنة      | risk=  0.0 | تم تفعيل باقتك الشهرية بنجاح. شكراً لاختيارك زين
# 🟢 رسالة آمنة      | risk=  0.0 | الراجحي: عملية شراء 500 ريال. للاستفسار: 920003344
# 🔴 تصيد احتيالي    | risk=  4.0 | مرحبا نبيل رئيس مشروع نيوم: ولي العهد وجه بإعداد لوائح ملائمة للا

# %% [markdown]
# ## 🎯 للـ Frontend Team
#
# ```python
# from defense.src.detector import PhishingDetector
# detector = PhishingDetector('defense/models/defence_model.pkl')
# result = detector.predict('نص الرسالة')
# # result = {'is_phishing': bool, 'label_ar': str, 'risk_score': float, 'flags': list, ...}
# ```
